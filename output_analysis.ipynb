# %%
import pandas as pd
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
### parameters ###

k = 5 # number of top codes to keep

# %%
def result_log(df, line):
    print('Text:')
    pp.pprint(df.loc[line]["text"])
    print('Code predicted:')
    print(df.loc[line]["top1_column"])
    print('Confidence:')
    print(df.loc[line]["top1_value"])

def select_top_k(k, df):
    result_df = df[['_id', 'target']]
    result_df.reset_index(drop = True, inplace = True)
    
    df_values = df.loc[:, ~df.columns.isin(['_id', 'target'])]
    
    result_df_values = pd.DataFrame()
    #create columns 
    for i in range(k):
        result_df_values['top{}_column'.format(i+1)] = None
        result_df_values['top{}_value'.format(i+1)] = None
    
    #set values to the new columns
    for i  in range(len(df_values)):
        top_k = df_values.iloc[i].sort_values(ascending= False)[:k]
        keys = top_k.index
        values = top_k.values
        
        keys_values = [item for pair in zip(keys, values) for item in pair]
    
        result_df_values.loc[i] = keys_values
        
    result_df = pd.concat([result_df, result_df_values], axis=1)

    return result_df

# %% [markdown]
# # Analyse MIMIC ICD

# %% [markdown]
# ## Macro

# %%
mimic_axa_data = pd.read_feather('files/data/mimic_axa_icd/mimic_axa_icd10.feather')

# %%
test_results = pd.read_feather('files/mimic_axa/predictions_test.feather')
test_results = test_results[-500:] #select last 500 rows
test_results_top_k = select_top_k(k=k, df = test_results)
test_results_top_k = test_results_top_k.merge(mimic_axa_data[['_id', 'text']], on = '_id')
test_results_top_k
# Out:
#           _id                                             target top1_column  \
# 0    26576572  [J44.1, Z79.02, E87.2, J96.92, E87.1, E66.9, G...      G47.33
# 1    26860865  [E87.2, S72.141A, K83.8, E87.1, I25.10, E78.5,...       Z95.1
# 2    21990791  [J18.9, F10.21, K65.2, E87.1, Y92.230, B19.20,...      K70.31
# 3    23999593  [R58., I25.10, K76.6, N18.3, B96.20, D62., D69...       N18.3
# 4    21485131  [Z85.79, K75.81, I25.10, K76.6, E78.5, R50.9, ...       N18.2
# ..        ...                                                ...         ...
# 495  25168203  [I48.0, I82.421, K65.9, R31.9, K57.32, E66.9, ...      I25.10
# 496  20094862  [I67.6, E79.0, R73.9, H57.02, E66.9, C90.00, Y...        E43.
# 497  22429647  [E87.1, E46., D68.4, Z78.1, D62., Z90.49, I48....      Z79.01
# 498  25077908  [E87.2, I42.8, A41.89, I82.622, I07.1, J80., E...       I42.0
# 499  23645412  [Z79.02, E87.0, J96.92, G92., Z68.42, I25.10, ...       Z95.1
#
#      top1_value top2_column  top2_value top3_column  top3_value top4_column  \
# 0      0.957063        I10.    0.907808       E78.5    0.879294       K21.9
# 1      0.969391      E11.65    0.965311    S72.141A    0.926209      I25.10
# 2      0.974383       K76.7    0.962007        I81.    0.954034        E43.
# 3      0.982522       Z95.1    0.962391       K21.9    0.954747       N17.9
# 4      0.950203       F32.9    0.947790        I81.    0.932105      K75.81
# ..          ...         ...         ...         ...         ...         ...
# 495    0.965500      I26.99    0.927452       Z95.5    0.922959     I82.431
# 496    0.983732     Z86.711    0.969907       N17.9    0.965293      C90.00
# 497    0.933163       Z79.4    0.886894      I48.91    0.864890      K91.89
# 498    0.866141       E03.9    0.861080     I82.622    0.827124       B37.0
# 499    0.969554       K76.6    0.938593       R18.8    0.928738       Z95.5
#
#      top4_value top5_column  top5_value  \
# 0      0.854116       J44.1    0.841102
# 1      0.908887       E78.5    0.906897
# 2      0.867934      I25.10    0.844359
# 3      0.931586      I25.10    0.911157
# 4      0.903965      I25.10    0.897869
# ..          ...         ...         ...
# 495    0.906833      K91.89    0.896912
# 496    0.950297      K59.00    0.943877
# 497    0.850498      R65.21    0.818824
# 498    0.805016     Z95.811    0.761795
# 499    0.879259      K31.89    0.872529
#
#                                                   text
# 0    name unit no admission date discharge date dat...
# 1    name unit no admission date discharge date dat...
# 2    name unit no admission date discharge date dat...
# 3    name unit no admission date discharge date dat...
# 4    name unit no admission date discharge date dat...
# ..                                                 ...
# 495  name unit no admission date discharge date dat...
# 496  name unit no admission date discharge date dat...
# 497  name unit no admission date discharge date dat...
# 498  name unit no admission date discharge date dat...
# 499  name unit no admission date discharge date dat...
#
# [500 rows x 13 columns]

# %% [markdown]
# ## Examples

# %%
result_log(test_results_top_k, 1)
# Out:
# Text:
# ('name unit no admission date discharge date date of birth sex m service '
#  'medicine allergies no known allergies adverse drug reactions attending chief '
#  'complaint right hip pain major surgical or invasive procedure right hip tfn '
#  'ercp with sphincterotomy flexible sigmoidoscopy history of present illness '
#  'yo speaking male with hld dm and cad s p cabg who was transferred from to on '
#  'after a mvc found to have a r intertrochanteric fracture planned for orif '
#  'with orthopedics now transferred to medicine due to difficult to control '
#  'blood sugars hyponatremia hyperkalemia and leukocytosis pt was a restrained '
#  'driver with no loc or headstrike during the above noted mvc and patient was '
#  'taken to for evaluation vs were t97 hr bp rr o2sat exam was notable for '
#  'diffuse pain with rom at the r hip with mild shortening mild tenderness to '
#  'palpation over paraspinal muscles but no midline tenderness and open skin '
#  'abrasions over dorsum of the r hand labs at notable for na k cl bun cr glu '
#  'anion gap wbc hgb alt ast ap tbili repeat labs showed na improved to k to '
#  'glu remained elevated at ekg was obtained which was noted as sinus with '
#  'bigeminy no peak t waves and was noted as nonischemic an xray was performed '
#  'and showed a significantly varus angulated intertrochanteric right proximal '
#  'femur fracture ct of the head and c spine were done as well and were overall '
#  'unremarkable full reads below pt received 1l ns calcium gluconate insulin 4u '
#  'due to inability for ortho hip repair at patient was transferred to on '
#  'transfer to pt was afebrile hr bp rr and he was on room air labs here showed '
#  'wbc hgb plt his exam was notable for an abrasion in the middle of the '
#  'abdomen superior to the umbilicus hip pain c w known injury ecchymosis and '
#  'skin tear on the dorsum of the l hand but no tenderness of hand and skin '
#  'tears over the left knee due to concern for mechanisms of injury and '
#  'abrasion over the midabdomen where pts seatbelt likely traversed the abdomen '
#  'a fast was performed which was negative of note pt did not get abdominal '
#  'imaging at osh hip x ray showed an intertrochanteric right proximal femur '
#  'fracture and cxr was negative orthopedics surgery were consulted and pt was '
#  'planned ot be admitted to orthopedics for orif intertrochanteric fixation on '
#  'the floor patients labs showed na k cl bicarb bun cr glu ca mg phos patient '
#  'received calcium gluconate g iv 10u insulin d50 magnesium sulfate gm iv and '
#  '1l ivf repeat labs showed improvement of k with na at ekg showed baseline '
#  'abnormalities but no peaked t waves or interval prolongation repeat glucose '
#  'remain elevated at was consulted for cardiac risk assessment and plan was '
#  'made for patient to be transferred to medicine for management of '
#  'hyperglycemia cad optimization and perioperative management of patients '
#  'multiple medical issues upon evaluation on the floor pt reports that a car '
#  'stopped abruptly ahead of him and he was unable to brake in time resulting '
#  'in the collision noted above pt reports that his leg got pushed back against '
#  'the dashboard ahead of him patient currently endorses right sided hip pain '
#  'but has no other complaints he denied head strike or loc and was a '
#  'restrained he further denied cp palpitations or lightheadedness prior to '
#  'event with no evidence of syncopal symptoms prior to the collision pt denies '
#  'a history of fevers chills ha n v diarrhea constipation chest pain with '
#  'exertion palpitations he does report intermittent swelling of his legs that '
#  'comes and goes he says that he sometimes gets short of breath with activity '
#  'he denies lightheadedness or syncope no orthopnea at home he says he is '
#  'fairly active in the warm weather months he walks several blocks per day he '
#  'also mows the lawn requires no assistance w walking climbs stairs in '
#  'speaking to patients outpatient cardiologist patient is prescribed asa 81mg '
#  'daily 40mg simvastatin daily furosemide 20mg daily glimepride 2mg daily and '
#  'metformin 1000mg bid however he is only compliant with metformin bid '
#  'patients last echo in showed ef of mild ar tr no as of note patient was not '
#  'able to tolerate bblocker therapy as an outpatient with profound sinus '
#  'bradycardia with hr in in clinic on 25mg daily of carvedilol and thus pt was '
#  'discontinued from this medication unfortunately per outpatient cardiologists '
#  'notes due to high copays patient has been resistant to undergo further '
#  'outpatient workup testing despite being advised to undergo furtherworkup of '
#  'note patient is followed for transient aflutter and is not on ac currently '
#  'past medical history past medical history aflutter not on ac cad with cabg '
#  'in diabetes hypertension hyperlipidemia cataract surgery bilaterally past '
#  'surgical history cabg in cataract surgery on r in l on social history family '
#  'history mother with disease physical exam admission exam avss nad a ox3 rle '
#  'incision well approximated dressing clean and dry fires fhl ta gcs silt n '
#  'distributions wwp distally discharge physical exam vitals ra general lying '
#  'in bed diminished affect cardiovascular rrr systolic murmur heard best at '
#  'rusb non radiating no extra heart sounds lungs clear to auscultation '
#  'bilaterally in anterior fields without wheezes rales rhonchi abdomen soft '
#  'abdomen distended diffusely minimal tenderness to palpation no rebound '
#  'guarding extremities mild dependent edema in thighs bilaterally skin no rash '
#  'appreicated msk rle thigh has orif surgical site c d i pertinent results '
#  'admission labs 55am blood wbc rbc hgb hct mcv mch mchc rdw rdwsd plt 55am '
#  'blood neuts lymphs monos eos baso im absneut abslymp absmono abseos absbaso '
#  '55am blood hypochr occasional anisocy normal poiklo normal macrocy normal '
#  'microcy normal polychr occasional 55am blood ptt 55am blood plt smr normal '
#  'plt 15am blood glucose urean creat na k cl hco3 angap 15am blood alt ast '
#  'alkphos totbili 33pm blood ck cpk 15am blood albumin calcium phos mg key '
#  'interim labs 33pm blood hba1c eag 33pm blood hbsag negative hbsab positive '
#  'hbcab positive hav ab positive igm hbc negative igm hav negative 20pm blood '
#  'crp 05am blood crp 33pm blood hcv ab negative 03pm blood glucose urean creat '
#  'na k cl hco3 angap 10am blood glucose urean creat na k cl hco3 angap 10am '
#  'blood glucose urean creat na k cl hco3 angap 50am blood glucose urean creat '
#  'na k cl hco3 angap discharge labs 15am blood wbc rbc hgb hct mcv mch mchc '
#  'rdw rdwsd plt 15am blood plt 15am blood ptt 15am blood glucose urean creat '
#  'na k cl hco3 angap 15am blood alt ast alkphos totbili 15am blood calcium '
#  'phos mg 55am blood po2 pco2 ph caltco2 base xs 55am blood lactate imaging '
#  'cxr no active intrathoracic process mild to moderate cardiomegaly although '
#  'no acute fracture or other chest wall lesion is seen conventional chest '
#  'radiographs are not sufficient for detection or characterization of most '
#  'such abnormalities if the demonstration of trauma to the chest wall is '
#  'clinically warranted the location of any referrable focal findings should be '
#  'clearly marked and imaged with either bone detail radiographs or chest ct '
#  'scanning hip fluoro images demonstrate fixation of a right femoral neck '
#  'fracture with a gamma nail total fluoroscopy time seconds echo the left '
#  'atrium is mildly dilated the right atrium is moderately dilated the '
#  'estimated right atrial pressure is mmhg there is mild symmetric left '
#  'ventricular hypertrophy the left ventricular cavity size is normal overall '
#  'left ventricular systolic function is normal lvef right ventricular chamber '
#  'size and free wall motion are normal the aortic arch is mildly dilated there '
#  'are focal calcifications in the aortic arch there are three aortic valve '
#  'leaflets the aortic valve leaflets are moderately thickened there is mild '
#  'aortic valve stenosis valve area 9cm2 the mitral valve leaflets are mildly '
#  'thickened mild mitral regurgitation is seen there is mild pulmonary artery '
#  'systolic hypertension there is no pericardial effusion ct torso mildly '
#  'dilated cbd measuring cm in diameter increased in size compared to the prior '
#  'ultrasound from correlation with liver function tests is recommended to rule '
#  'out a new obstruction nonspecific ill defined hypodensities within the '
#  'central liver differential considerations include microabscess neoplasm such '
#  'as cholangiocarcinoma is less likely as there is no bile duct dilatation '
#  'component of fatty liver or hepatic infarct is unlikely diffuse wall '
#  'thickening of the rectum with presacral edema concerning for proctitis '
#  'clinical correlation is necessary to rule out infectious or inflammatory '
#  'etiology extensive arterial disease as described above mostly '
#  'atherosclerotic involvement of left gastric artery raises possibility of '
#  'sequela of dissection of indeterminate age appearance of spleen and kidney '
#  'suggest chronic infarcts or sequela of chronic infection in the right kidney '
#  'mrcp non mass like area of mild t2 hyperintensity at the hepatic hilum with '
#  'heterogenous hyperenhancement in the early arterial phase is suboptimally '
#  'characterized on subsequent dynamic enhancement images due to motion '
#  'artifact there is a small subcentimeter fluid collection in the midst of '
#  'this lesion this suggests a focal area of cholangitis with a small abscess '
#  'there is a small predominantly tubular filling defect in the proximal cbd as '
#  'well as mild dilatation of the cbd and intrahepatic bile ducts this may '
#  'represent a small stone with sludge just sludge or pus ercp advised mm '
#  'cystic lesion in the pancreatic body without enhancement consistent with a '
#  'side branch ipmn a year follow up mri should be considered femur ap lat '
#  'plain film in comparison with study of there has been placement of a '
#  'fixation device about and intertrochanteric fracture of the right femur '
#  'minimal offset of the fracture fragments but nothing to indicate that '
#  'healing is not taking place satisfactorily no hardware related complication '
#  'lower extremity ultrasound no evidence of deep venous thrombosis in the '
#  'right or left lower extremity veins ct lower extremity no convincing '
#  'evidence of infection involving the right lower extremity within the '
#  'limitations of ct imaging please note mr is more sensitive for the detection '
#  'of osteomyelitis ct abd pelvis no evidence for fluid collection or abscess '
#  'persistent wall thickening of the rectum raises possibility of proctitis '
#  'underlying mass cannot be excluded further evaluation with endoscopy is '
#  'recommended heterogeneous appearance of the liver better visualized on '
#  'contrast enhanced examination needs to be further evaluated with mri as '
#  'neoplasm such as cholangiocarcinoma cannot be excluded hip pa lat plain film '
#  'postoperative changes of orif for right femoral neck fracture are seen '
#  'orientation of the fracture fragments is similar compared to immediate '
#  'postop films overlying skin staples are noted no interval fracture pubic '
#  'symphysis and si joints are preserved soft tissues are unremarkable other '
#  'studies flex sig biopsy preliminary focal active colitis with ulceration no '
#  'granulomas dysplasia or histologic evidence of chronic injury seen ercp the '
#  'scout film was normal normal major papilla was noted with in a large '
#  'duodenal diverticula cannulation of the biliary duct was successful and deep '
#  'with a sphincterotome using a free hand technique contrast medium was '
#  'injected resulting in complete opacification there was mild proximal '
#  'dilation with no obvious stricture distally few distal cbd filling defects '
#  'representing sludge were noted at the distal cbd a sphincterotomy was '
#  'performed in the o clock position using a sphincterotome over an existing '
#  'guidewire there was no evidence of post sphincterotomy bleeding due to '
#  'difficult position a sphincteroplasty was performed using a cre balloon up '
#  'to mm balloon sweeps were performed of the common bile duct which yielded '
#  'sludge further sweeps were performed until no debris was noted completion '
#  'occlusion cholangiogram revealed no further filling defects post balloon '
#  'sweeps good contrast and bile drainage was noted both endoscopically and '
#  'fluoroscopically otherwise normal ercp to third part of the duodenum '
#  'microbiology no growth on any culture except for the mrsa screen sputum gram '
#  'stain final respiratory culture preliminary inpatient blood culture blood '
#  'culture routine pending inpatient urine urine culture pending inpatient '
#  'blood culture blood culture routine pending inpatient stool c difficile dna '
#  'amplification assay final inpatient urine urine culture final inpatient '
#  'sputum gram stain final respiratory culture final inpatient mrsa screen mrsa '
#  'screen final positive for methicillin resistant staph aureus inpatient blood '
#  'culture blood culture routine final inpatient blood culture blood culture '
#  'routine final inpatient urine urine culture final inpatient brief hospital '
#  'course mr is an yo portugese speaking m with hld dm and cad s p cabg who '
#  'presented after a mvc found to have r intertrochanteric fracture he '
#  'underwent surgical repair with a transfemoral nail his postoperative course '
#  'was complicated by hyperglycemia likely cholangitis acute kidney injury '
#  'likely contrast induced nephropathy and proctitis he was managed on the '
#  'medicine service for these problems and was discharged in stable condition '
#  'to rehab r intertrochanteric fracture on admission patient was evaluated by '
#  'the orthopedic surgery team and was found to have a right intertrochanteric '
#  'hip fracture the patient was taken to the operating room on for right hip '
#  'tfn which the patient tolerated well of note patient received 1u prbc '
#  'intraop with ebl 50cc the patient was taken from the or to the pacu in '
#  'stable condition and after satisfactory recovery from anesthesia was '
#  'transferred to the floor patient was followed by orthopedic surgery and '
#  'progressed to weight bearing as tolerated in the rle staples were removed on '
#  'pod and plan will be for f u on in the orthopedics clinic leukocytosis '
#  'patient s postoperative course was complicated by uptrending leukocytosis '
#  'with bands and elevated crp this was initially thought to be due to focal '
#  'cholangitis given fluid collection at hepatic hilum and cbd dilatation he '
#  'underwent ercp as detailed below after the procedure his leukocytosis '
#  'continued to be elevated and his platelets rose as well id was consulted and '
#  'he underwent further imaging eventually this source of this second '
#  'leukocytosis was thought to be proctitis as detailed below he completed a '
#  'day course of ctx flagyl after his ercp with improvement of his leukocytosis '
#  'cholangitis as above patient was noted to have transaminitis with cbd '
#  'dilatation on imaging the ercp team was consulted and he underwent a ercp '
#  'procedure on he had several balloon sweeps clearing out biliary sludge and a '
#  'sphincterotomy was performed subsequently his lfts normalized with the '
#  'exception of alk phos which was and stable at time of discharge he was '
#  'treated with ceftriaxone flagyl for days following ercp at the '
#  'recommendation of the ercp team proctitis patient was noted on ct abdomen to '
#  'have evidence of proctitis the gi team was consulted and a flex sig with '
#  'biopsies was performed on on the flex sig a 10cm area of friable ulceration '
#  'was seen in the rectum the preliminary path from the scan showed focal '
#  'active colitis with ulceration most consistent with stercoral colitis final '
#  'biopsies pending at time of discharge atrial flutter patient found to be in '
#  'aflutter consistent with known history of transient aflutter in the past '
#  'previously had not tolerated beta blockade bradycardic to on carvedilol on '
#  'this admission was initiated on metoprolol xl initially at 50mg which was '
#  'downtitrated to 25mg due to bradycardia on metoprolol succinate 25mg daily '
#  'his heart rates were stable systemic anticoagulation for patient s aflutter '
#  'was discussed with cardiologist dr decision was made to initiate apixaban '
#  '5mg bid however this was held due to acute kidney injury and bloody stools '
#  'described below on discharge he was not on any anticoagulation and this was '
#  'deferred to outpatient setting after resolution of his bloody stools and '
#  'uncontrolled type diabetes at home patient is on oral regimen presented with '
#  'hyperglycemia likely related to acute stress in setting of fracture patients '
#  'insulin regimen was slowly uptitrated of note patient has hgba1c of '
#  'indicating poor bg control as outpatient patient s blood glucose control '
#  'improved however his insulin will need to be uptitrated as his renal '
#  'function improves coronary artery disease s p cabg patient was continued on '
#  'asa 81mg daily and initiated on beta blocker as above underwent repeat echo '
#  'which showed no regional wall motion abnormalities with ef mild symmetric '
#  'lvh aortic valve thickening mild mr mild pulmonary artery systolic htn and '
#  'mild av valve stenosis acute kidney injury patient was noted to have a '
#  'rapidly uptrending creatinine postoperatively with muddy brown casts on '
#  'sediment this was thought to represent contrast induced nephropathy his '
#  'urine output initially decreased to 700cc per day his creatinine peaked at '
#  'subsequently both his urine output and creatinine improved with supportive '
#  'care cr downtrending to at time of discharge transitional issues patient is '
#  's p orif with transfemoral nail for hip fracture will follow up in clinic on '
#  'with orthopedic surgery postop dvt prophylaxis please continue sc heparin '
#  'for month postop last day please check creatinine in week to ensure '
#  'continued improvement from contrast induced nephropathy discharge cr please '
#  'check hb hct in week to ensure stability discharge hb for patient s aflutter '
#  'chads vasc anticoagulation with apixaban was held at time of discharge due '
#  'to acute kidney injury and bloody stools please discuss restarting '
#  'anticoagulation with dr as outpatient hypertension patient was noted to have '
#  'sbp in the 160s please start on losartan for dmii and htn once renal '
#  'function improves please check fingersticks qid and uptitrate insulin as '
#  'creatinine improves hba1c was and patient will require insulin long term '
#  'patient endorsing symptoms of depression please consider initiating ssri as '
#  'outpatient heterogenous liver seen on imaging please consider mri of the '
#  'liver as outpatient to assess for mass patient has fh of cholangiocarcinoma '
#  'flex sig biopsy results pending our gi team will follow up with his '
#  'outpatient pcp dr any critical findings please arrange formal outpatient '
#  'neurocognitive testing patient was seen by ot who noted patient had '
#  'difficulty with step commands and recommended pt should not be driving until '
#  'more formal evaluation occurred code status full medications on admission '
#  'the preadmission medication list is accurate and complete simvastatin mg po '
#  'qpm metformin glucophage mg po bid glimepiride mg oral daily aspirin mg po '
#  'daily discharge medications acetaminophen mg po q8h rx acetaminophen mg '
#  'tablet s by mouth every six hours disp tablet refills docusate sodium mg po '
#  'bid heparin unit sc tid glargine units breakfast humalog units breakfast '
#  'humalog units lunch humalog units dinner insulin sc sliding scale using hum '
#  'insulin lidocaine patch ptch td qam metoprolol succinate xl mg po daily '
#  'polyethylene glycol g po daily senna mg po bid constipation hold for loose '
#  'stools tamsulosin mg po qhs aspirin mg po daily simvastatin mg po qpm '
#  'discharge disposition extended care facility discharge diagnosis right '
#  'intertrochanteric hip fracture discharge condition mental status clear and '
#  'coherent level of consciousness alert and interactive activity status '
#  'ambulatory requires assistance or aid walker or cane discharge instructions '
#  'dear mr you were admitted to due to a broken hip our orthopedic surgeons '
#  'performed a surgery to repair your hip after your surgery you had a number '
#  'of problems which were managed on the medicine service including high blood '
#  'sugars an infection in the liver called cholangitis inflammation and ulcer '
#  'in the rectum called proctitis fast heart rate called atrial flutter we have '
#  'started you on a number of new medications that are very important to take '
#  'you will need follow up in clinic with your primary care doctor dr you will '
#  'also need to follow up with our orthopaedic surgeons it is extremely '
#  'important to keep these appointments and continue taking your medicines we '
#  'wish you all the best your care team followup instructions')
# Code predicted:
# Z95.1
# Confidence:
# 0.96939117

# %% [markdown]
# # Analyse MIMIC-AXA ICD

# %% [markdown]
# ## Macro

# %%
axa_data = pd.read_feather('files/data/axa_icd10/axa_icd10.feather')
ids_axa = list(axa_data['_id'])

# %%
val_results = pd.read_feather('files/mimic_axa/predictions_val.feather')
val_results_axa = val_results[val_results['_id'].isin(ids_axa)]
val_results_axa_top_k = select_top_k(k=k, df = val_results_axa)
val_results_axa_top_k = val_results_axa_top_k.merge(axa_data[['_id', 'text']], on = '_id')
val_results_axa_top_k
# Out:
#          _id   target top1_column  top1_value top2_column  top2_value  \
# 0   13117700  [Z71.8]       Z32.1    0.269132       Z71.8    0.049279
# 1   13285005  [Z71.8]       Z32.1    0.269132       Z71.8    0.049279
# 2   13067682  [J93.1]       Z32.1    0.175665       Z71.8    0.075976
# 3   13230779    [A09]       Z32.1    0.055442       Z71.8    0.045934
# 4   13430163  [M51.1]       M51.1    0.708517     M48.061    0.064162
# 5   13199485  [Z32.1]       Z32.1    0.524967       Z71.8    0.066648
# 6   12935394  [Z32.1]       Z32.1    0.859061         S93    0.109357
# 7   13100091  [Z32.1]       Z32.1    0.807568         S93    0.058492
# 8   13224756  [Q40.1]       Z32.1    0.125357         S93    0.092911
# 9   13386965  [Z32.1]       Z32.1    0.816483       Z71.8    0.046660
# 10  13370915  [Z32.1]       Z32.1    0.846353         S93    0.067886
# 11  13036749    [D25]       Z32.1    0.066281       Z71.8    0.033136
# 12  13348684  [Z32.1]       Z32.1    0.906372         S93    0.061802
# 13  13335869  [M51.1]       M51.1    0.136106      M54.16    0.065542
# 14  13019625    [S93]         S93    0.053035       Z32.1    0.049423
# 15  13066291  [D39.1]       Z32.1    0.316304       C78.6    0.219734
# 16  13285431  [Z32.1]       Z32.1    0.942889         S93    0.066013
# 17  13355028  [M23.8]         M23    0.148288       Z32.1    0.045276
# 18  13261372  [Z32.1]       Z32.1    0.757540       Z71.8    0.026954
# 19  13018667    [S93]       Z32.1    0.032970       Z71.8    0.031036
# 20  13323964    [S52]       Z32.1    0.051036       Z71.8    0.048584
# 21  13411340    [S93]       Z32.1    0.034347       Z71.8    0.032353
# 22  13023411    [D05]       Z17.0    0.408926       C77.3    0.327004
# 23  13510623  [Z32.1]       Z32.1    0.934990         S93    0.109649
# 24  13034627  [U07.1]       K21.9    0.039313       J98.4    0.026564
# 25  13298349    [S01]       Z32.1    0.036264       Z71.8    0.034257
# 26  13397738  [Z71.8]      G47.33    0.317714       Z32.1    0.027003
# 27  13453325    [S61]         S93    0.027181       Z71.8    0.024815
# 28  13298980  [S61.0]         S93    0.062996         M23    0.054282
# 29  12999417    [E10]      K86.81    0.103152       Z32.1    0.098386
# 30  13412966  [J34.2]       J34.2    0.851659    S02.2XXA    0.142160
# 31  13412226  [M51.1]       M51.1    0.312913       Z92.3    0.119944
# 32  13247984  [S43.0]         S93    0.110511         M23    0.046944
# 33  13439744  [S00.8]         S93    0.034156        Z23.    0.029571
# 34  13153840  [J34.2]       J34.2    0.602949       R04.0    0.150824
# 35  13368584  [S93.4]         S93    0.086158        Z23.    0.018478
# 36  12963190  [S52.3]        I10.    0.470257       R03.0    0.195885
# 37  12917239    [G35]        G35.    0.886129       Z99.3    0.064163
# 38  13279515    [K21]      K29.80    0.502024       K21.9    0.337584
# 39  12871685    [M75]    W10.9XXA    0.287156    W10.8XXA    0.253368
# 40  13195579    [K35]       Y83.8    0.241549       K66.0    0.215286
# 41  13361127  [S62.6]        Z23.    0.045578       S68.3    0.033739
# 42  13300775    [M23]      Y92.39    0.084365        Z23.    0.041124
# 43  13037246    [M23]       F41.9    0.039460       Z71.8    0.033955
# 44  13423517    [M23]         M23    0.186818     Z87.891    0.052694
# 45  13018651    [S62]       F41.9    0.031208     Z85.830    0.026509
#
#    top3_column  top3_value top4_column  top4_value top5_column  top5_value  \
# 0          S93    0.037659       M51.1    0.022750       U07.1    0.022151
# 1          S93    0.037659       M51.1    0.022750       U07.1    0.022151
# 2          S93    0.055621         S01    0.043133       U07.1    0.033669
# 3          S93    0.035508        Z23.    0.026060       U07.1    0.018586
# 4        Z71.8    0.058990       Z32.1    0.057656         S93    0.047867
# 5          S93    0.057682        Z23.    0.029644       M51.1    0.029338
# 6        Z71.8    0.088751       M51.1    0.055600         S01    0.032615
# 7        Z71.8    0.055710        Z23.    0.034882       U07.1    0.024374
# 8        Z71.8    0.078219       K21.9    0.061460       K44.9    0.059905
# 9          S93    0.041094        Z23.    0.021045       U07.1    0.017104
# 10       Z71.8    0.064010       M51.1    0.028344        Z23.    0.024530
# 11         S93    0.026116        Z23.    0.017964       U07.1    0.012449
# 12       Z71.8    0.057413        Z23.    0.020139       M51.1    0.018785
# 13       Z71.8    0.047118       Z32.1    0.046162         S93    0.039093
# 14       Z71.8    0.046523        Z23.    0.018496       U07.1    0.017095
# 15       C56.2    0.213000       C56.9    0.175943       C56.1    0.096419
# 16       Z71.8    0.056260       M51.1    0.022755        Z23.    0.019531
# 17         S93    0.043042       M51.1    0.041098       Z71.8    0.036194
# 18         S93    0.025805        Z23.    0.016108       U07.1    0.010795
# 19         S93    0.025694        Z23.    0.016672       U07.1    0.014203
# 20         S93    0.038663       U07.1    0.018067        Z23.    0.016745
# 21         S93    0.025601        Z23.    0.015173       U07.1    0.013882
# 22       Z17.1    0.321452     C50.911    0.213486         D05    0.183381
# 23       Z71.8    0.093697       M51.1    0.052767     O99.011    0.042849
# 24        Z23.    0.018519       J47.9    0.010197       J21.9    0.009901
# 25         S93    0.026661        Z23.    0.015581       U07.1    0.014178
# 26      G47.30    0.021242       Z71.8    0.017109        Z23.    0.016404
# 27       Z32.1    0.023898        Z23.    0.015777       U07.1    0.010039
# 28       Z71.8    0.049935       Z32.1    0.035107         S62    0.027180
# 29       R73.9    0.058235       E11.9    0.049960      R73.01    0.039150
# 30       R04.0    0.124757     J45.909    0.063542       F41.9    0.054712
# 31      Z92.21    0.051735      M48.06    0.024288       I73.9    0.024004
# 32       Z32.1    0.033088         M75    0.026876        Z23.    0.024223
# 33     Z87.820    0.028240       Z32.1    0.024653       Z71.8    0.020051
# 34        Z23.    0.018221      Z86.73    0.015986         S93    0.015493
# 35         M23    0.017882       Z32.1    0.017341    S82.851A    0.015872
# 36       F41.9    0.064742         D05    0.055748    W19.XXXA    0.049598
# 37        Z23.    0.014011     Z86.718    0.011266       E66.9    0.009241
# 38      R10.13    0.114615       F41.9    0.062327      Z92.21    0.061182
# 39      M75.42    0.097365     Y92.008    0.091032     M25.512    0.077763
# 40       R11.2    0.190425     Y92.234    0.178002      Z90.49    0.161621
# 41    S66.123A    0.017330     F17.210    0.016691       Y92.9    0.014953
# 42     M25.561    0.039834    W50.0XXA    0.015925     F17.210    0.015295
# 43        Z23.    0.030530       Z32.1    0.026833         S93    0.023932
# 44        Z23.    0.020246       M23.8    0.018186       E66.9    0.013685
# 45        Z23.    0.025917     F17.210    0.023757         D05    0.020925
#
#                                                  text
# 0   current disease cause of disease diagnostic tr...
# 1   current disease cause of disease diagnostic tr...
# 2   current disease cause of disease diagnostic ex...
# 3   current disease cause of disease bacterial dia...
# 4   current disease post operated lumbar instrumen...
# 5   current disease i prevent post resumer electiv...
# 6   current disease secondary amenorhea due to pre...
# 7   current disease di de bicemal biar twin pregna...
# 8   current disease patient with presence of parae...
# 9   current disease without uterine activity witho...
# 10  current disease pregnancy of by fun intrauteri...
# 11  current disease present in the last months pol...
# 12  current disease without uterine activity witho...
# 13  current disease umbar pain months evolution ca...
# 14  current disease forced movement ankle followin...
# 15  current disease icd c incidental right ovarian...
# 16  current disease typical of pregnancy cause of ...
# 17  current disease accident during physical activ...
# 18  current disease pricing this with normal evolu...
# 19  current disease iriveracer forced ankle laguid...
# 20  current disease patient who solves ceide with ...
# 21  current disease diagnosis of multiple mirlome ...
# 22  current disease she went to the consultation o...
# 23  current disease patient with pregnancy of week...
# 24  current disease non productive cough in attack...
# 25  current disease turkish suffering on at am suf...
# 26  current disease nocturnal snoring that causes ...
# 27  current disease the condition began when he su...
# 28  current disease it starts in september with a ...
# 29  current disease he went for metabolic control ...
# 30  current disease accidental nasal trauma second...
# 31  current disease female patient referring level...
# 32  current disease fall from his own height a sca...
# 33  current disease mild tce wound in the occipita...
# 34  current disease it begins presenting nasal obs...
# 35  current disease patient presented spontaneousl...
# 36  current disease cause of disease a m approx fa...
# 37  current disease it began in with hypoesthesia ...
# 38  current disease a year old male patient presen...
# 39  current disease left omalgia ganglions in supr...
# 40  current disease after the fourth week post ape...
# 41  current disease he starts secondary to be doin...
# 42  current disease patient who when playing socce...
# 43  current disease laida de prodia altura when mo...
# 44  current disease dx post operated acl plasty me...
# 45  current disease ailment the patient comes to v...

# %% [markdown]
# ## Examples

# %%
result_log(val_results_axa_top_k, 45)
# Out:
# Text:
# ('current disease ailment the patient comes to vyveces par having presented '
#  'care with a truma in the left hand for which he started candola and '
#  'imitation e f edens it equiiny functional hand dollar to the pulp without '
#  'distal neurocinelatin compromise ailment the patient comes to vyveces par '
#  'having presented care with a truma in the left hand for which he started '
#  'candola and imitation e f edens it equiiny functional hand dollar to the '
#  'pulp without distal neurocinelatin compromise ailment the patient comes to '
#  'vyveces par having presented care with a truma in the left hand for which he '
#  'started candola and imitation e f edens it equiiny functional hand dollar to '
#  'the pulp without distal neurocinelatin compromise cause of disease time '
#  'manner and place where the injury occurred loss of full sustenance it is '
#  'related to another condition yestime manner and place where the injury '
#  'occurred loss of full sustenance it is related to another condition yestime '
#  'manner and place where the injury occurred loss of full support it is '
#  'related to another condition yes no diagnostic recent sto metacarpal '
#  'fracture and cerich icd code recent sto metacarpal fracture and cerich icd '
#  'code recent sto metacarpal fracture and cerich icd code treatment no '
#  'qunnergicono qunnergicono qunnergico')
# Code predicted:
# F41.9
# Confidence:
# 0.031207642

# %%
result_log(val_results_axa_top_k, 37)
# Out:
# Text:
# ('current disease it began in with hypoesthesia in the lower limbs and '
#  'stabbing pain in the medial aspect of the right thigh a thoracic lumbar '
#  'spine mri was performed finding a hyperintense spinal cord lesion on t2 '
#  'sequence and stir at the level of the ninth and tenth thoracic vertebrae of '
#  'demyelinating characteristics it was complemented with mri of the skull for '
#  'periventricular lesions the diagnosis of multiple sclerosis was made cause '
#  'of disease relapsing remitting multiple sclerosis diagnostic relapsing '
#  'remitting multiple sclerosis pain in the left leg that limits walking '
#  'persistent pain in the proximal and posterolateral region of the thigh and '
#  'leg of a neuropathic radicular type treatment teriflunomide mg dia')
# Code predicted:
# G35.
# Confidence:
# 0.88612944

# %%
result_log(val_results_axa_top_k, 38)
# Out:
# Text:
# ('current disease a year old male patient presents docon casteldia aby dominac '
#  'burgclismos pyrosis liquid evaluations with the presence of sonore despite '
#  'having attended to the general physician clausultation there is no mejuria '
#  'he is a prisoner20 year old male patient commonly epigastric mesogastrium '
#  'borgmismotireregurgitations pyrosis docor vente in cord colic acute dock tor '
#  'distensind abdul inac with nocardiac ref with severe gastroesophageal '
#  'causing nocturnal hitogos of mocta mooscopy with cos findings it is '
#  'determined cause of disease acode to castroein outpatient office te mologia '
#  'uonte la situation of fish symptomatology se medimca endoscopy cooking '
#  'diagnostic ci therapeutic diagnostic itiatc hernia type severe cardiofiatal '
#  'incontinence gastrito erojive iemorrhagic erosive duodenitis seanexan images '
#  'treatment')
# Code predicted:
# K29.80
# Confidence:
# 0.5020244

# %% [markdown]
# # Analyse MIMIC AXA CPT

# %% [markdown]
# ## Macro

# %%
axa_data = pd.read_feather('files/data/axa_cpt/axa_cpt.feather')
ids_axa = list(axa_data['_id'])

# %%
val_results = pd.read_feather('files/mimic_axa_cpt_hierarchical/predictions_val.feather')
val_results_axa = val_results[val_results['_id'].isin(ids_axa)]
val_results_axa_top_k = select_top_k(k=k, df = val_results_axa)
val_results_axa_top_k = val_results_axa_top_k.merge(axa_data[['_id', 'text']], on = '_id')
val_results_axa_top_k
# Out:
#         _id   target top1_column  top1_value top2_column  top2_value  \
# 0  13437099  [97010]       99204    0.542491       97010    0.227312
# 1  13480889  [99204]       94003    0.216795       99253    0.180926
# 2  13398568  [99204]       99253    0.277833       25608    0.241016
#
#   top3_column  top3_value top4_column  top4_value top5_column  top5_value  \
# 0       99284    0.082261       99291    0.060866       99232    0.038395
# 1       99254    0.167006       11012    0.160366       94002    0.131133
# 2       25605    0.235559       25600    0.197673       94003    0.176286
#
#                                                 text
# 0  cause of disease degenerative actual disease t...
# 1  cause of disease accident forced inversion of ...
# 2  cause of disease fall with impact on the left ...

# %%
test_results = pd.read_feather('files/mimic_axa_cpt_hierarchical/predictions_test.feather')
test_results_axa = test_results[test_results['_id'].isin(ids_axa)]
test_results_axa_top_k = select_top_k(k=k, df = test_results_axa)
test_results_axa_top_k = test_results_axa_top_k.merge(axa_data[['_id', 'text']], on = '_id')
test_results_axa_top_k
# Out:
#         _id          target top1_column  top1_value top2_column  top2_value  \
# 0  13100771  [99284, 15852]       99204    0.541795       97010    0.228145
# 1  13021869         [99204]       99204    0.543174       97010    0.230861
# 2  13127804         [99204]       99204    0.307167       99253    0.133405
# 3  13116727  [97010, 99204]       99204    0.316768       97010    0.157504
#
#   top3_column  top3_value top4_column  top4_value top5_column  top5_value  \
# 0       99284    0.082800       99291    0.057959       99232    0.036797
# 1       99284    0.083379       99291    0.057961       99232    0.037600
# 2       99254    0.122027       97010    0.113378       99231    0.076276
# 3       99291    0.087305       99232    0.052821       99233    0.042024
#
#                                                 text
# 0  cause of disease wounded by a firearm projecti...
# 1  cause of disease uncontrolled primary hypothyr...
# 2  cause of disease indirect trauma to the left a...
# 3  cause of disease dopamine deficiency idiopathi...

# %% [markdown]
# ## Examples

# %%
result_log(val_results_axa_top_k, 2)
# Out:
# Text:
# ('cause of disease fall with impact on the left thoracic limb fall with impact '
#  'on the left thoracic limb fall with impact on the left thoracic limb fall '
#  'with impact on the left thoracic limb actual disease a year old female '
#  'patient was sent with the diagnosis of left distal radius fracture he refers '
#  'that he does not present pain but does have limitation of mobility and '
#  'muscular weakness fall with impact on the left thoracic limb with one week '
#  'of evolution which was attended in the emergency due to a fracture in the '
#  'distal radius and managed with closed reduction and placement of a '
#  'fiberglass appliance palmar brachy and presenting pain with radiography in '
#  'which an angulation of greater than degrees is observed fall with impact on '
#  'the left thoracic extremity of one week of evolution that was attended in '
#  'the emergency for fracture in the distal radius and managed with closed '
#  'reduction and fiber appliance placement glass shield and presenting pain '
#  'with a radiograph in which an angulation of greater than degrees is observed '
#  'year old female patient sent with the diagnosis of left distal radius '
#  'fracture she reports that she does not present pain but does have limited '
#  'mobility and weakness muscular diagnostic left distal radius fracture left '
#  'distal radius fracture left distal radius fracture left distal radius '
#  'fracture treatment emergency attention reduction and osteosynthesis on the '
#  'left radio brachipalmar device of fiberglass medical speciality orthopedics '
#  'rehabilitation rehabilitation orthopedics')
# Code predicted:
# 99253
# Confidence:
# 0.27783278

# %%
result_log(test_results_axa_top_k, 1)
# Out:
# Text:
# ('cause of disease uncontrolled primary hypothyroidism and impaired cardiac '
#  'function sec to aortic stenosis actual disease anything diagnostic the '
#  'patient reported that she started approximately weeks prior to the '
#  'consultation with dyspnea on great exertion as well as pain in the right '
#  'hemithorax asthenia adynamia and increased dyspnea were added to the picture '
#  'until it was from small efforts right pleural effusion uncontrolled primary '
#  'hypothyroidism aortic stenosis congestive heart failure treatment diagnostic '
#  'therapeutic thoracocentesis medical speciality internal medicine')
# Code predicted:
# 99204
# Confidence:
# 0.5431741
